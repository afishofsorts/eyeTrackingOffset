# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt
import os

dir_list = os.listdir('Primary Care Calibration\\Manually Validated Participants')
calList = pandas.read_excel('Primary Care Calibration\\Manually Validated Participants\\Calibration List.xlsx').to_numpy()

inds = np.zeros(len(dir_list)-1)
for i in range(len(dir_list)-1):
    if calList[i, 1]=='Good':
        inds[i] = 1

# %%
import statistics as stat

coms = np.zeros(shape=(3, int(sum(inds))))
m=0
for i in range(len(dir_list)-1):
    if inds[i]==1:
        data = pandas.read_csv('Primary Care Calibration\\Manually Validated Participants\\' + str(dir_list[i+1])).to_numpy()
        for l in range(len(data[:, 0])):
            if data[l, 4]<0 or data[l, 5]<0:
                data[l, 3] = 0

        validData = np.zeros(shape=(int(sum(data[:, 3])), 6))

        j = 0
        for k in range(len(data[:, 0])):
            if data[k, 3] == 1:
                validData[j, :] = data[k, :]
                j= j + 1

        coms[0, m] = stat.fmean(validData[:, 4])
        coms[1, m] = stat.fmean(validData[:, 5])
        coms[2, m] = int(sum(data[:, 3]))
        m = m+1

print(stat.fmean(coms[0, :]))
print(stat.fmean(coms[1, :]))

np.save('clusterData\\gen_com', coms)

plt.plot(coms[0, :], coms[1, :], 'o')
plt.title('General Center of Masses')
plt.xlim(0, 1920); plt.ylim(0, 1080)
plt.show()
# Out:
# 997.3884360055428
# 460.39347340903305

# %%
xmin = 0; xmax = 550
ymin = 200; ymax = 600

coms = np.zeros(shape=(3, int(sum(inds))))
m=0
for i in range(len(dir_list)-1):
    if inds[i]==1:
        data = pandas.read_csv('Primary Care Calibration\\Manually Validated Participants\\' + str(dir_list[i+1])).to_numpy()
        for l in range(len(data[:, 0])):
            if data[l, 4]<xmin or data[l, 4]>xmax or data[l, 5]<ymin or data[l, 5]>ymax:
                data[l, 3] = 0

        validData = np.zeros(shape=(int(sum(data[:, 3])), 6))

        j = 0
        for k in range(len(data[:, 0])):
            if data[k, 3] == 1:
                validData[j, :] = data[k, :]
                j= j + 1

        coms[0, m] = stat.fmean(validData[:, 4])
        coms[1, m] = stat.fmean(validData[:, 5])
        coms[2, m] = int(sum(data[:, 3]))
        m = m+1

np.save('clusterData\\sidem_com', coms)

plt.plot(coms[0, :], coms[1, :], 'o')
plt.title('Side Mirror Center of Mass')
plt.xlim(0, 1920); plt.ylim(0, 1080)
plt.show()

# %%
xmin = 820; xmax = 1000
ymin = 200; ymax = 400

coms = np.zeros(shape=(3, int(sum(inds))))
m=0
for i in range(len(dir_list)-1):
    if inds[i]==1:
        data = pandas.read_csv('Primary Care Calibration\\Manually Validated Participants\\' + str(dir_list[i+1])).to_numpy()
        for l in range(len(data[:, 0])):
            if data[l, 4]<xmin or data[l, 4]>xmax or data[l, 5]<ymin or data[l, 5]>ymax:
                data[l, 3] = 0

        validData = np.zeros(shape=(int(sum(data[:, 3])), 6))

        j = 0
        for k in range(len(data[:, 0])):
            if data[k, 3] == 1:
                validData[j, :] = data[k, :]
                j= j + 1

        coms[0, m] = stat.fmean(validData[:, 4])
        coms[1, m] = stat.fmean(validData[:, 5])
        coms[2, m] = int(sum(data[:, 3]))
        m = m+1

np.save('clusterData\\speedom_com', coms)

plt.plot(coms[0, :], coms[1, :], 'o')
plt.title('Speedometer Center of Mass')
plt.xlim(0, 1920); plt.ylim(0, 1080)
plt.show()

# %%
xmin = 1250; xmax = 1900
ymin = 540; ymax = 800

coms = np.zeros(shape=(3, int(sum(inds))))
m=0
for i in range(len(dir_list)-1):
    if inds[i]==1:
        data = pandas.read_csv('Primary Care Calibration\\Manually Validated Participants\\' + str(dir_list[i+1])).to_numpy()
        for l in range(len(data[:, 0])):
            if data[l, 4]<xmin or data[l, 4]>xmax or data[l, 5]<ymin or data[l, 5]>ymax:
                data[l, 3] = 0

        validData = np.zeros(shape=(int(sum(data[:, 3])), 6))

        j = 0
        for k in range(len(data[:, 0])):
            if data[k, 3] == 1:
                validData[j, :] = data[k, :]
                j= j + 1

        coms[0, m] = stat.fmean(validData[:, 4])
        coms[1, m] = stat.fmean(validData[:, 5])
        coms[2, m] = int(sum(data[:, 3]))
        m = m+1

np.save('clusterData\\rv_com', coms)

plt.plot(coms[0, :], coms[1, :], 'o')
plt.title('Rearview Center of Mass')
plt.xlim(0, 1920); plt.ylim(0, 1080)
plt.show()

# %%
xmin = 600; xmax = 1050
ymin = 400; ymax = 550

coms = np.zeros(shape=(3, int(sum(inds))))
m=0
for i in range(len(dir_list)-1):
    if inds[i]==1:
        data = pandas.read_csv('Primary Care Calibration\\Manually Validated Participants\\' + str(dir_list[i+1])).to_numpy()
        for l in range(len(data[:, 0])):
            if data[l, 4]<xmin or data[l, 4]>xmax or data[l, 5]<ymin or data[l, 5]>ymax:
                data[l, 3] = 0

        validData = np.zeros(shape=(int(sum(data[:, 3])), 6))

        j = 0
        for k in range(len(data[:, 0])):
            if data[k, 3] == 1:
                validData[j, :] = data[k, :]
                j= j + 1

        coms[0, m] = stat.fmean(validData[:, 4])
        coms[1, m] = stat.fmean(validData[:, 5])
        coms[2, m] = int(sum(data[:, 3]))
        m = m+1

np.save('clusterData\\road_com', coms)

plt.plot(coms[0, :], coms[1, :], 'o')
plt.title('Road Center of Mass')
plt.xlim(0, 1920); plt.ylim(0, 1080)
plt.show()

# %%
xmin = 1240; xmax = 1640
ymin = 0; ymax = 270

coms = np.zeros(shape=(3, int(sum(inds))))
m=0
for i in range(len(dir_list)-1):
    if inds[i]==1:
        data = pandas.read_csv('Primary Care Calibration\\Manually Validated Participants\\' + str(dir_list[i+1])).to_numpy()
        for l in range(len(data[:, 0])):
            if data[l, 4]<xmin or data[l, 4]>xmax or data[l, 5]<ymin or data[l, 5]>ymax:
                data[l, 3] = 0

        validData = np.zeros(shape=(int(sum(data[:, 3])), 6))

        j = 0
        for k in range(len(data[:, 0])):
            if data[k, 3] == 1:
                validData[j, :] = data[k, :]
                j= j + 1

        coms[0, m] = stat.fmean(validData[:, 4])
        coms[1, m] = stat.fmean(validData[:, 5])
        coms[2, m] = int(sum(data[:, 3]))
        m = m+1

np.save('clusterData\\panel_com', coms)

plt.plot(coms[0, :], coms[1, :], 'o')
plt.title('Panel Center of Mass')
plt.xlim(0, 1920); plt.ylim(0, 1080)
plt.show()
